# %% [markdown]
# <a href="https://colab.research.google.com/github/nadunchanna98/machine-learning-research/blob/main/practive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Import data set from my google drive

# %%
import os
os.chdir('/content/drive/My Drive/RESEACH/DATASET1/')

# %%
import pandas as pd
data = pd.read_csv('miRNA_HiSeq_gene1.csv')

# %%
data.head(10)
# Out:
#          sample  TCGA-BI-A0VS-01  TCGA-C5-A1MP-01  TCGA-C5-A2M1-01  \
# 0  MIMAT0019868         0.151000           0.2034         0.291900
# 1  MIMAT0019869         0.151000              NaN              NaN
# 2  MIMAT0019860              NaN              NaN              NaN
# 3  MIMAT0019861              NaN              NaN              NaN
# 4  MIMAT0019862         0.287700              NaN              NaN
# 5  MIMAT0019864              NaN              NaN         0.291900
# 6  MIMAT0019865         0.412545              NaN         0.291900
# 7  MIMAT0019866              NaN              NaN              NaN
# 8  MIMAT0019867         0.412600           0.2034         0.534563
# 9  MIMAT0027483         0.287700              NaN              NaN
#
#    TCGA-VS-A94Z-01  TCGA-C5-A2M2-01  TCGA-Q1-A5R3-01  TCGA-Q1-A5R2-01  \
# 0         0.791266              NaN           0.2542              NaN
# 1              NaN              NaN              NaN              NaN
# ...

# %%
df1 = pd.read_csv('TCGA.CESC.sampleMap_CESC_clinicalMatrix.csv')
df2 = pd.read_csv('miRNA_HiSeq_gene1.csv')

# %%
df1
# Out:
#             sampleID     _INTEGRATION      _PATIENT  \
# 0    TCGA-2W-A8YY-01  TCGA-2W-A8YY-01  TCGA-2W-A8YY
# 1    TCGA-4J-AA1J-01  TCGA-4J-AA1J-01  TCGA-4J-AA1J
# 2    TCGA-BI-A0VR-01  TCGA-BI-A0VR-01  TCGA-BI-A0VR
# 3    TCGA-BI-A0VS-01  TCGA-BI-A0VS-01  TCGA-BI-A0VS
# 4    TCGA-BI-A20A-01  TCGA-BI-A20A-01  TCGA-BI-A20A
# ..               ...              ...           ...
# 308  TCGA-ZJ-AAXT-01  TCGA-ZJ-AAXT-01  TCGA-ZJ-AAXT
# 309  TCGA-ZJ-AAXU-01  TCGA-ZJ-AAXU-01  TCGA-ZJ-AAXU
# 310  TCGA-ZJ-AB0H-01  TCGA-ZJ-AB0H-01  TCGA-ZJ-AB0H
# 311  TCGA-ZJ-AB0I-01  TCGA-ZJ-AB0I-01  TCGA-ZJ-AB0I
# 312  TCGA-ZX-AA5X-01  TCGA-ZX-AA5X-01  TCGA-ZX-AA5X
#
#                          _cohort                _primary_disease  \
# 0    TCGA Cervical Cancer (CESC)  cervical & endocervical cancer
# 1    TCGA Cervical Cancer (CESC)  cervical & endocervical cancer
# 2    TCGA Cervical Cancer (CESC)  cervical & endocervical cancer
# 3    TCGA Cervical Cancer (CESC)  cervical & endocervical cancer
# ...
